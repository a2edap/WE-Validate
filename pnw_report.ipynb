# %% [markdown]
# Usage:
# 1. Edit configuration files
#     (a) Specify validation time, analysis, and metrics
#         (i) if analysis contains 'swing-door', specify a threshold (default is 0.1)
#     (b) Put datasets to be compared in path
#     (c) If you wish to print metrics/show figures, make sure to enable them
# 2. Run the following with Shift + Enter/Return
#     (a) The default of the compare function is to run config.yaml, to run a different configuration file, simply specify it in the compare function, e.g. compare('config_BH2.yaml')

# %%
import os
import pathlib
import sys
import subprocess 
from weasyprint import HTML

sys.path.append(str(pathlib.Path(os.getcwd()).parent))

# main routine of we-validate
from wevalidate_csv import compare

# %%
# %reload_ext autoreload
# %autoreload 2

compare('PNW_centr_config/config_BH1.yaml')
# Out:
# ********** for PNW_BH1: **********
#
# ********** for WRF Centroid Actual: **********
#
# DETECTED 1440 MISSING TIME STEPS.
# THEY WILL BE HANDLED AUTOMATICALLY.
#
# aligning the 1-minute baseline data (PNW_BH1) to match the
# 5-minute comparison data (WRF Centroid Actual), at the end of the
# measurement period using the instance method
#
# evaluate PNW_BH1, WRF Centroid Actual from 2016-08-02 00:00:00 to 2016-08-30 00:00:00
# every 5.0 minutes, total of 8065 time steps
#
# !!!!!!!!!!
# WARNING: DESIRED EVALUATION DURATION DOES NOT MATCH DATA DURATION
# DESIRED: FROM 2016-08-01 00:00:00 TO 2016-08-31 23:55:00
# DATA: FROM 2016-08-02 00:00:00 TO 2016-08-30 00:00:00
# !!!!!!!!!!
#
# !!!!!!!!!!
# WARNING: DATA FREQUENCY DOES NOT MATCH DESIRED EVALUATION PERIOD FREQUENCY
# SHOULD HAVE 8928.0 TIME STEPS IN DATA
# ONLY HAVE 8065 TIME STEPS IN DATA
# !!!!!!!!!!
# Metrics for metrics_base_analysis_WRF Centroid Actual_MS:
#                  rmse      crmse      bias  bias_pct        mae    mae_pct  \
# 2016-08-01  45.204001  44.109141  9.888648   4.96917  27.840868  13.990386
#
#             cross_correlation
# 2016-08-01           0.746759
# Metrics for metrics_swingdoor-mag_WRF Centroid Actual_MS:
#                  rmse      crmse       bias   bias_pct        mae    mae_pct  \
# 2016-08-01  82.789758  58.901773  58.178392  29.235373  58.178392  29.235373
#
#             cross_correlation
# 2016-08-01       1.284661e-15
# Metrics for metrics_swingdoor-ramp_WRF Centroid Actual_MS:
# Empty DataFrame
# Columns: [rmse, crmse, bias, bias_pct, mae, mae_pct, cross_correlation]
# Index: []
# Metrics for metrics_swingdoor-dur_WRF Centroid Actual_MS:
#               rmse  crmse    bias     bias_pct     mae      mae_pct  \
# 2016-08-01  8029.0    0.0 -8029.0 -4034.673367  8029.0  4034.673367
#
#             cross_correlation
# 2016-08-01                NaN
#
# ********** for WRF Centroid A1: **********
#
# DETECTED 1440 MISSING TIME STEPS.
# THEY WILL BE HANDLED AUTOMATICALLY.
#
# aligning the 1-minute baseline data (PNW_BH1) to match the
# 5-minute comparison data (WRF Centroid A1), at the end of the
# measurement period using the instance method
#
# evaluate PNW_BH1, WRF Centroid A1 from 2016-08-02 00:00:00 to 2016-08-30 00:00:00
# every 5.0 minutes, total of 8065 time steps
#
# !!!!!!!!!!
# WARNING: DESIRED EVALUATION DURATION DOES NOT MATCH DATA DURATION
# DESIRED: FROM 2016-08-01 00:00:00 TO 2016-08-31 23:55:00
# DATA: FROM 2016-08-02 00:00:00 TO 2016-08-30 00:00:00
# !!!!!!!!!!
#
# !!!!!!!!!!
# WARNING: DATA FREQUENCY DOES NOT MATCH DESIRED EVALUATION PERIOD FREQUENCY
# SHOULD HAVE 8928.0 TIME STEPS IN DATA
# ONLY HAVE 8065 TIME STEPS IN DATA
# !!!!!!!!!!
# /Users/hend622/miniforge3/envs/test_env/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3037: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /Users/hend622/miniforge3/envs/test_env/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2894: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /Users/hend622/miniforge3/envs/test_env/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2894: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# Metrics for metrics_base_analysis_WRF Centroid A1_MS:
#                  rmse      crmse       bias   bias_pct        mae    mae_pct  \
# 2016-08-01  62.056096  54.518446  29.642844  14.895901  38.825104  19.510102
#
#             cross_correlation
# 2016-08-01           0.720973
# Metrics for metrics_swingdoor-mag_WRF Centroid A1_MS:
#                   rmse      crmse       bias   bias_pct        mae    mae_pct  \
# 2016-08-01  108.062077  71.871086  80.696714  40.551112  80.696714  40.551112
#
#             cross_correlation
# 2016-08-01       1.123841e-15
# Metrics for metrics_swingdoor-ramp_WRF Centroid A1_MS:
# Empty DataFrame
# Columns: [rmse, crmse, bias, bias_pct, mae, mae_pct, cross_correlation]
# Index: []
# Metrics for metrics_swingdoor-dur_WRF Centroid A1_MS:
#               rmse  crmse    bias     bias_pct     mae      mae_pct  \
# 2016-08-01  8030.0    0.0 -8030.0 -4035.175879  8030.0  4035.175879
#
#             cross_correlation
# 2016-08-01                NaN
#
# ********** for WRF Centroid A2: **********
#
# DETECTED 1440 MISSING TIME STEPS.
# THEY WILL BE HANDLED AUTOMATICALLY.
#
# aligning the 1-minute baseline data (PNW_BH1) to match the
# 5-minute comparison data (WRF Centroid A2), at the end of the
# measurement period using the instance method
#
# evaluate PNW_BH1, WRF Centroid A2 from 2016-08-02 00:00:00 to 2016-08-30 00:00:00
# every 5.0 minutes, total of 8065 time steps
#
# !!!!!!!!!!
# WARNING: DESIRED EVALUATION DURATION DOES NOT MATCH DATA DURATION
# DESIRED: FROM 2016-08-01 00:00:00 TO 2016-08-31 23:55:00
# DATA: FROM 2016-08-02 00:00:00 TO 2016-08-30 00:00:00
# !!!!!!!!!!
#
# !!!!!!!!!!
# WARNING: DATA FREQUENCY DOES NOT MATCH DESIRED EVALUATION PERIOD FREQUENCY
# SHOULD HAVE 8928.0 TIME STEPS IN DATA
# ONLY HAVE 8065 TIME STEPS IN DATA
# !!!!!!!!!!
# /Users/hend622/miniforge3/envs/test_env/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3037: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /Users/hend622/miniforge3/envs/test_env/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2894: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /Users/hend622/miniforge3/envs/test_env/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2894: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# Metrics for metrics_base_analysis_WRF Centroid A2_MS:
#                  rmse     crmse       bias   bias_pct        mae    mae_pct  \
# 2016-08-01  63.060829  55.45985  30.014549  15.082688  39.647094  19.923163
#
#             cross_correlation
# 2016-08-01             0.7312
# Metrics for metrics_swingdoor-mag_WRF Centroid A2_MS:
#                   rmse      crmse       bias   bias_pct        mae    mae_pct  \
# 2016-08-01  109.555905  74.425685  80.394737  40.399365  80.394737  40.399365
#
#             cross_correlation
# 2016-08-01      -1.823451e-16
# Metrics for metrics_swingdoor-ramp_WRF Centroid A2_MS:
# Empty DataFrame
# Columns: [rmse, crmse, bias, bias_pct, mae, mae_pct, cross_correlation]
# Index: []
# Metrics for metrics_swingdoor-dur_WRF Centroid A2_MS:
#               rmse  crmse    bias     bias_pct     mae      mae_pct  \
# 2016-08-01  8030.0    0.0 -8030.0 -4035.175879  8030.0  4035.175879
#
#             cross_correlation
# 2016-08-01                NaN
#
# ********** for WRF Centroid A3: **********
#
# DETECTED 1440 MISSING TIME STEPS.
# THEY WILL BE HANDLED AUTOMATICALLY.
#
# aligning the 1-minute baseline data (PNW_BH1) to match the
# 5-minute comparison data (WRF Centroid A3), at the end of the
# measurement period using the instance method
#
# evaluate PNW_BH1, WRF Centroid A3 from 2016-08-02 00:00:00 to 2016-08-30 00:00:00
# every 5.0 minutes, total of 8065 time steps
#
# !!!!!!!!!!
# WARNING: DESIRED EVALUATION DURATION DOES NOT MATCH DATA DURATION
# DESIRED: FROM 2016-08-01 00:00:00 TO 2016-08-31 23:55:00
# DATA: FROM 2016-08-02 00:00:00 TO 2016-08-30 00:00:00
# !!!!!!!!!!
#
# !!!!!!!!!!
# WARNING: DATA FREQUENCY DOES NOT MATCH DESIRED EVALUATION PERIOD FREQUENCY
# SHOULD HAVE 8928.0 TIME STEPS IN DATA
# ONLY HAVE 8065 TIME STEPS IN DATA
# !!!!!!!!!!
# /Users/hend622/miniforge3/envs/test_env/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3037: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /Users/hend622/miniforge3/envs/test_env/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2894: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /Users/hend622/miniforge3/envs/test_env/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2894: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# Metrics for metrics_base_analysis_WRF Centroid A3_MS:
#                 rmse     crmse     bias  bias_pct        mae    mae_pct  \
# 2016-08-01  64.88256  56.90433  31.1712  15.66392  41.119607  20.663119
#
#             cross_correlation
# 2016-08-01           0.741711
# Metrics for metrics_swingdoor-mag_WRF Centroid A3_MS:
#                   rmse      crmse       bias   bias_pct        mae    mae_pct  \
# 2016-08-01  111.644984  78.244188  79.639498  40.019848  79.639498  40.019848
#
#             cross_correlation
# 2016-08-01       9.023818e-16
# Metrics for metrics_swingdoor-ramp_WRF Centroid A3_MS:
# Empty DataFrame
# Columns: [rmse, crmse, bias, bias_pct, mae, mae_pct, cross_correlation]
# Index: []
# Metrics for metrics_swingdoor-dur_WRF Centroid A3_MS:
#               rmse  crmse    bias     bias_pct     mae      mae_pct  \
# 2016-08-01  8029.0    0.0 -8029.0 -4034.673367  8029.0  4034.673367
#
#             cross_correlation
# 2016-08-01                NaN
# /Users/hend622/miniforge3/envs/test_env/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3037: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /Users/hend622/miniforge3/envs/test_env/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2894: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /Users/hend622/miniforge3/envs/test_env/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2894: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
