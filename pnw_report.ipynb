# %% [markdown]
# Usage:
# 1. Edit configuration files
#     (a) Specify validation time, analysis, and metrics
#         (i) if analysis contains 'swing-door', specify a threshold (default is 0.1)
#     (b) Put datasets to be compared in path
#     (c) If you wish to print metrics/show figures, make sure to enable them
# 2. Run the following with Shift + Enter/Return
#     (a) The default of the compare function is to run config.yaml, to run a different configuration file, simply specify it in the compare function, e.g. compare('config_BH2.yaml')

# %%
import os
import pathlib
import sys 

sys.path.append(str(pathlib.Path(os.getcwd()).parent))

# main routine of we-validate
from wevalidate_csv import compare

# %%
# %reload_ext autoreload
# %autoreload 2

compare('PNW_config/config_BH1.yaml')
# Out:
# ********** for PNW_BH1: **********
#
# ********** for WRF Centroid Actual: **********
# Warning: 6227 negative values found.
# Negative values have been set to 0.
#
# DETECTED 1440 MISSING TIME STEPS.
# THEY WILL BE HANDLED AUTOMATICALLY.
#
# aligning the 1-minute baseline data (PNW_BH1) to match the
# 5-minute comparison data (WRF Centroid Actual), at the end of the
# measurement period using the average method
#
# evaluate PNW_BH1, WRF Centroid Actual from 2016-08-02 00:00:00 to 2016-08-29 23:55:00
# every 5.0 minutes, total of 8064 time steps
#
# !!!!!!!!!!
# WARNING: DESIRED EVALUATION DURATION DOES NOT MATCH DATA DURATION
# DESIRED: FROM 2016-08-02 00:00:00 TO 2016-08-31 23:55:00
# DATA: FROM 2016-08-02 00:00:00 TO 2016-08-29 23:55:00
# !!!!!!!!!!
#
# !!!!!!!!!!
# WARNING: DATA FREQUENCY DOES NOT MATCH DESIRED EVALUATION PERIOD FREQUENCY
# SHOULD HAVE 8640.0 TIME STEPS IN DATA
# ONLY HAVE 8064 TIME STEPS IN DATA
# !!!!!!!!!!
# Keys in aggregation_results: ['MS', 'MS_day', 'MS_night']
# Metrics for metrics_base_analysis_WRF Centroid Actual_MS_average_5min:
#                  rmse     crmse     bias        mae  bias_pct    mae_pct  \
# 2016-08-01  45.019227  43.99666  9.54069  27.457837  4.794317  13.797908
#
#             cross_correlation        ovl
# 2016-08-01           0.747289  68.727882
#
# ********** for WRF Turbine Actual: **********
# Warning: 6227 negative values found.
# Negative values have been set to 0.
#
# DETECTED 1440 MISSING TIME STEPS.
# THEY WILL BE HANDLED AUTOMATICALLY.
#
# aligning the 1-minute baseline data (PNW_BH1) to match the
# 5-minute comparison data (WRF Turbine Actual), at the end of the
# measurement period using the average method
#
# evaluate PNW_BH1, WRF Turbine Actual from 2016-08-02 00:00:00 to 2016-08-29 23:55:00
# every 5.0 minutes, total of 8064 time steps
#
# !!!!!!!!!!
# WARNING: DESIRED EVALUATION DURATION DOES NOT MATCH DATA DURATION
# DESIRED: FROM 2016-08-02 00:00:00 TO 2016-08-31 23:55:00
# DATA: FROM 2016-08-02 00:00:00 TO 2016-08-29 23:55:00
# !!!!!!!!!!
#
# !!!!!!!!!!
# WARNING: DATA FREQUENCY DOES NOT MATCH DESIRED EVALUATION PERIOD FREQUENCY
# SHOULD HAVE 8640.0 TIME STEPS IN DATA
# ONLY HAVE 8064 TIME STEPS IN DATA
# !!!!!!!!!!
# Keys in aggregation_results: ['MS', 'MS_day', 'MS_night']
# Metrics for metrics_base_analysis_WRF Turbine Actual_MS_average_5min:
#                  rmse      crmse      bias        mae  bias_pct   mae_pct  \
# 2016-08-01  42.121603  40.934255  9.930569  25.254672  4.990236  12.69079
#
#             cross_correlation        ovl
# 2016-08-01           0.771777  72.518011
